# %%
# %pip install nltk
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')  # for newer NLTK versions
# Out:
# Requirement already satisfied: nltk in c:\users\hp\miniconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: click in c:\users\hp\miniconda3\lib\site-packages (from nltk) (8.2.1)
# Requirement already satisfied: joblib in c:\users\hp\miniconda3\lib\site-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\hp\miniconda3\lib\site-packages (from nltk) (2025.9.18)
# Requirement already satisfied: tqdm in c:\users\hp\miniconda3\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in c:\users\hp\miniconda3\lib\site-packages (from click->nltk) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
corpus="""Hello Welcome all to victor's nlp learning related to 
machine learning git-repo , hope you enjoy and gain some stuff here.
"""

# %%
print(corpus)
# Out:
# Hello Welcome all to victor's nlp learning related to
# machine learning git-repo , hope you enjoy and gain some stuff here.

# %%
##  Tokenization
## Sentence-->paragraphs
from nltk.tokenize import sent_tokenize

# %%
documents=sent_tokenize(corpus)

# %%
print(documents)
# Out:
# ["Hello Welcome all to victor's nlp learning related to \nmachine learning git-repo , hope you enjoy and gain some stuff here."]

# %%
type(documents)
# Out:
# list

# %%
for sentence in documents:
    print(sentence)
# Out:
# Hello Welcome all to victor's nlp learning related to
# machine learning git-repo , hope you enjoy and gain some stuff here.

# %%
## Tokenization 
## Paragraph-->words
## sentence--->words
from nltk.tokenize import word_tokenize

# %%
word_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  'all',
#  'to',
#  'victor',
#  "'s",
#  'nlp',
#  'learning',
#  'related',
#  'to',
#  'machine',
#  'learning',
#  'git-repo',
#  ',',
#  'hope',
#  'you',
#  'enjoy',
#  'and',
#  'gain',
#  'some',
#  'stuff',
#  'here',
#  '.']

# %%
for sentence in documents:
    print(word_tokenize(sentence))
# Out:
# ['Hello', 'Welcome', 'all', 'to', 'victor', "'s", 'nlp', 'learning', 'related', 'to', 'machine', 'learning', 'git-repo', ',', 'hope', 'you', 'enjoy', 'and', 'gain', 'some', 'stuff', 'here', '.']

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
wordpunct_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  'all',
#  'to',
#  'victor',
#  "'",
#  's',
#  'nlp',
#  'learning',
#  'related',
#  'to',
#  'machine',
#  'learning',
#  'git',
#  '-',
#  'repo',
#  ',',
#  'hope',
#  'you',
#  'enjoy',
#  'and',
#  'gain',
#  'some',
#  'stuff',
#  'here',
#  '.']

# %%
from nltk.tokenize import TreebankWordTokenizer

# %%
tokenizer=TreebankWordTokenizer()

# %%
tokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  'all',
#  'to',
#  'victor',
#  "'s",
#  'nlp',
#  'learning',
#  'related',
#  'to',
#  'machine',
#  'learning',
#  'git-repo',
#  ',',
#  'hope',
#  'you',
#  'enjoy',
#  'and',
#  'gain',
#  'some',
#  'stuff',
#  'here',
#  '.']
